# %% [markdown]
# ### Install environment

# %%
# !git clone https://thanhson28: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@github.com/thanhson28/cheapfakes_detection_icmr2024.git
# %cd cheapfakes_detection_icmr2024
# %cd /content/cheapfakes_detection_icmr2024
# !sed '1d' requirements.txt | xargs -I {} pip install {}
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1hRJ91urYg8EbU8Hgy6s2xhkCMoeRtYBJ
# !pip install "numpy<1.24"
# %cd /content/cheapfakes_detection_icmr2024/fairseq
# !pip install ./
# %cd /content/cheapfakes_detection_icmr2024/run_scripts/snli_ve
# Out:
# fatal: destination path 'cheapfakes_detection_icmr2024' already exists and is not an empty directory.
# /content/cheapfakes_detection_icmr2024
# /content/cheapfakes_detection_icmr2024
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (0.9.16)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)
# Requirement already satisfied: ftfy==6.0.3 in /usr/local/lib/python3.10/dist-packages (6.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3) (0.2.13)
# Requirement already satisfied: tensorboardX==2.4.1 in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX==2.4.1) (1.23.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from tensorboardX==2.4.1) (3.20.3)
# Collecting pycocotools==2.0.4
#   Using cached pycocotools-2.0.4.tar.gz (106 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0.4) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0.4) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.4) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0.4) (1.16.0)
# Building wheels for collected packages: pycocotools
#   error: subprocess-exited-with-error
#
#   × Building wheel for pycocotools (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for pycocotools (pyproject.toml) ... error
#   ERROR: Failed building wheel for pycocotools
# Failed to build pycocotools
# ERROR: Could not build wheels for pycocotools, which is required to install pyproject.toml-based projects
# Requirement already satisfied: pycocoevalcap==1.2 in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap==1.2) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.16.0)
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.23.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.10.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (0.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.2)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.10.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.3.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: Levenshtein==0.25.0 in /usr/local/lib/python3.10/dist-packages (from python-Levenshtein) (0.25.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.25.0->python-Levenshtein) (3.6.2)
# Requirement already satisfied: zhconv in /usr/local/lib/python3.10/dist-packages (1.4.3)
# Requirement already satisfied: pypinyin==0.47.1 in /usr/local/lib/python3.10/dist-packages (0.47.1)
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (1.23.5)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (3.8.1)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (7.0.0)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (0.1.3)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=0.3.1->g2p_en) (2.6.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from inflect>=0.3.1->g2p_en) (4.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (4.66.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect>=0.3.1->g2p_en) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect>=0.3.1->g2p_en) (2.16.3)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1hRJ91urYg8EbU8Hgy6s2xhkCMoeRtYBJ
# From (redirected): https://drive.usercontent.google.com/download?id=1hRJ91urYg8EbU8Hgy6s2xhkCMoeRtYBJ&confirm=t&uuid=0144afdf-4a4f-4c4e-9ea0-2205615f0be5
# To: /content/cheapfakes_detection_icmr2024/checkpoint.best_snli_score_0.9010.pt
# 100% 2.62G/2.62G [00:32<00:00, 80.7MB/s]
# Requirement already satisfied: numpy<1.24 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# /content/cheapfakes_detection_icmr2024/fairseq
# Processing /content/cheapfakes_detection_icmr2024/fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (1.16.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (3.0.9)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (1.0.7)
# Requirement already satisfied: omegaconf<2.1 in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (2.0.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (2023.12.25)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (2.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (4.66.2)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (2.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fairseq==1.0.0a0+35f24f1) (1.23.5)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.10/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq==1.0.0a0+35f24f1) (4.8)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq==1.0.0a0+35f24f1) (6.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq==1.0.0a0+35f24f1) (4.10.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==1.0.0a0+35f24f1) (2.8.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==1.0.0a0+35f24f1) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==1.0.0a0+35f24f1) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==1.0.0a0+35f24f1) (4.9.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq==1.0.0a0+35f24f1) (2.21)
# Building wheels for collected packages: fairseq
#   Building wheel for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-1.0.0a0+35f24f1-cp310-cp310-linux_x86_64.whl size=2786526 sha256=fb60c741f91fcde2e92ab61eadff27119949f1412457153de517975d107b4620
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v07mjymp/wheels/3b/9a/54/992e1e16efb29a9aae9e4956eab4ec2c00b8d757f246595ad3
# Successfully built fairseq
# Installing collected packages: fairseq
#   Attempting uninstall: fairseq
#     Found existing installation: fairseq 1.0.0a0+35f24f1
#     Uninstalling fairseq-1.0.0a0+35f24f1:
#       Successfully uninstalled fairseq-1.0.0a0+35f24f1
# Successfully installed fairseq-1.0.0a0+35f24f1

# %% [markdown]
# ### INPUT_FOLDER structure:
# - INPUT_FOLDER should has structure as same as requirement of organizer, contain "test.json" as follow:\
# INPUT_FOLDER \
# ├── test.json \
# ├── test \
# │   ├── 0.jpg \
# │   ├── 100.png \
# │   ├── 101.jpg \
# │   ├── 102.jpg \
# - With "test/0.jpg" is an "img_local_path" in "test.json" for example.

# %% [markdown]
# ### SETUP Enviroment variables - you should change to adapt your data folder structure
# - IMG_PREFIX: absulutely path to parent folder which contains images folder
# - DATA: absolutely path to test.json file of organizer
# - If the "img_local_path" in "test.json" is "test/0.jpg", the absulutely path to the image have to be IMG_PREFIX/test/0.jpg

# %%
# %env IMG_PREFIX=/content/drive/MyDrive/cosmos/data/acm
# %env DATA=/content/drive/MyDrive/cosmos/data/acm/test.json
# Out:
# env: IMG_PREFIX=/content/drive/MyDrive/cosmos/data/acm
# env: DATA=/content/drive/MyDrive/cosmos/data/acm/test.json

# %% [markdown]
# ### Run experiment for task 1

# %%
# %env MASTER_PORT=7091

# %env user_dir=../../ofa_module
# %env bpe_dir=../../utils/BPE

# dev or test
# %env split=test
# %env data={DATA}
# %env path=/content/cheapfakes_detection_icmr2024/checkpoint.best_snli_score_0.9010.pt
# %env result_path=../../results/snli_ve
# %env selected_cols=0,2,3,4,5

# !CUDA_VISIBLE_DEVICES=0 python ../../inference.py \
    ${data} \
    --path=${path}\
    --user-dir=${user_dir} \
    --task=snli_ve \
    --batch-size=2 \
    --log-format=simple --log-interval=10 \
    --seed=7 \
    --gen-subset=${split} \
    --results-path=${result_path} \
    --fp16 \
    --num-workers=0 \
    --model-overrides="{\"data\":\"${data}\",\"bpe_dir\":\"${bpe_dir}\",\"selected_cols\":\"${selected_cols}\"}"
# Out:
# env: MASTER_PORT=7091
# env: user_dir=../../ofa_module
# env: bpe_dir=../../utils/BPE
# env: split=test
# env: data=/content/drive/MyDrive/cosmos/data/acm/test.json
# env: path=/content/cheapfakes_detection_icmr2024/checkpoint.best_snli_score_0.9010.pt
# env: result_path=../../results/snli_ve
# env: selected_cols=0,2,3,4,5
# 2024-03-09 16:46:46.782446: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-09 16:46:46.782506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-09 16:46:46.784346: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-09 16:46:46.794742: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-09 16:46:48.394916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-09 16:46:53 | INFO | datasets | PyTorch version 2.1.0+cu121 available.
# 2024-03-09 16:46:53 | INFO | datasets | TensorFlow version 2.15.0 available.
# 2024-03-09 16:46:53 | INFO | datasets | JAX version 0.4.23 available.
# 2024-03-09 16:46:57 | INFO | ofa.evaluate | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 10, 'log_format': 'simple', 'log_file': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 7, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': '../../ofa_module', 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': '/content/cheapfakes_detection_icmr2024/checkpoint.best_snli_score_0.9010.pt', 'post_process': None, 'quiet': False, 'model_overrides': '{"data":"/content/drive/MyDrive/cosmos/data/acm/test.json","bpe_dir":"../../utils/BPE","selected_cols":"0,2,3,4,5"}', 'results_path': '../../results/snli_ve'}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_algorithm': 'LocalSGD', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False}, 'dataset': {'_name': None, 'num_workers': 0, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 2, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 2, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_all_dp_ranks': False, 'write_checkpoints_asynchronously': False, 'model_ ...
# 2024-03-09 16:46:57 | INFO | ofa.evaluate | loading model(s) from /content/cheapfakes_detection_icmr2024/checkpoint.best_snli_score_0.9010.pt
# 2024-03-09 16:46:58 | INFO | tasks.ofa_task | source dictionary: 59457 types
# 2024-03-09 16:46:58 | INFO | tasks.ofa_task | target dictionary: 59457 types
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# local datafile temp.tsv slice_id 0 begin to initialize row_count and line_idx-to-offset mapping
# local datafile temp.tsv slice_id 0 finished initializing row_count and line_idx-to-offset mapping
# file temp.tsv slice_id 0 row count 1 total row count 1
# 0it [00:00, ?it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.1837, -1.7853, -9.7217]], device='cuda:0', grad_fn=<CatBackward0>)
# 501it [00:00, 519.93it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4426e+01, -8.3446e-07, -1.5156e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3007e-05, -1.0688e+01, -1.5495e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0257,  -3.6741, -11.2874]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5722e+01, -2.1458e-06, -1.3111e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.5497e-06, -1.3482e+01, -1.6548e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.7762e-05, -1.0951e+01, -1.5090e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.5299e-06, -1.2424e+01, -1.4593e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.0797e-06, -1.2039e+01, -1.5750e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-9.5005e-05, -9.3009e+00, -1.2510e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.1921e-07, -1.5798e+01, -1.7341e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.7434e-04, -8.3306e+00, -8.3638e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-06, -1.2971e+01, -1.6797e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0208, -3.9270, -7.0559]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1629e+01, -2.3007e-05, -1.1172e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.1563e-05, -1.2027e+01, -1.2102e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.2489e-04, -7.2351e+00, -1.2465e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-19.4092,   0.0000, -17.2827]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.4846e+00, -2.1968e-04, -1.1252e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.8441e+00, -3.9319e-04, -1.3799e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3990e+01, -1.6808e-05, -1.1043e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2495e+01, -3.2782e-05, -1.0445e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.0299e-04, -9.2071e+00, -1.2833e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.5946e-03, -5.4030e+00, -9.4196e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2111e+01, -1.2517e-05, -1.1860e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7521e+01, -1.1921e-07, -1.5940e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.3205e-05, -9.4884e+00, -1.1795e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1412e+01, -2.5510e-05, -1.1143e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.5814e-05, -1.0032e+01, -1.0355e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-2.1551, -0.1277, -5.5222]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.7418e-06, -1.2869e+01, -1.6263e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.8702e+00, -5.8888e-05, -1.1837e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1775e+01, -9.1791e-06, -1.3438e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.8610e-06, -1.3043e+01, -1.4227e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.9141e-06, -1.1879e+01, -1.6886e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3202e+01, -3.5763e-06, -1.3258e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.2531e-03, -5.7298e+00, -1.6318e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0781e+01, -2.3842e-05, -1.2689e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.4544, -1.0403, -4.4387]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.7434e-04, -8.3306e+00, -8.3638e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-2.0951e+01, -1.1921e-07, -1.6363e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.5755e+01, -1.6360e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-22.5039,   0.0000, -17.7523]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.8481e+00, -4.4455e-04, -9.8276e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4129e+01, -2.9802e-06, -1.3027e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.3009,  -1.3477, -12.6231]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.4729e-05, -1.0701e+01, -1.0072e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.5762e-05, -1.0262e+01, -1.3964e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.3060e-05, -9.8087e+00, -1.1726e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2359e+01, -1.3113e-05, -1.1639e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[  0.0000, -17.5271, -18.4409]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.3446e-07, -1.4131e+01, -1.5986e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.8876e-06, -1.3168e+01, -1.2737e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 553it [00:09, 44.21it/s] [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1670e+01, -1.0014e-05, -1.3433e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0105, -4.5730, -9.4382]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1479e+01, -1.3471e-05, -1.2660e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.7219e-05, -1.0182e+01, -1.0856e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.9337e+00, -8.3562e-05, -1.0259e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-3.0561, -0.0483, -9.0532]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1574e+01, -1.0252e-05, -1.4032e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.9802e-06, -1.2783e+01, -1.6189e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.5763e-07, -1.5082e+01, -1.6621e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6028e+01, -8.3446e-07, -1.4205e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-4.8594e+00, -7.7942e-03, -1.1678e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0230,  -3.7847, -11.5254]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.3768e-04, -8.9162e+00, -1.2561e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2199e+01, -6.9141e-06, -1.3201e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4156e+01, -2.3842e-06, -1.3333e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5560e+01, -2.3842e-07, -1.6284e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.8381e+01, -2.3842e-07, -1.5595e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.4702e+00, -1.4690e-03, -7.0151e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4305e-06, -1.4195e+01, -1.4169e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.8237e+01, -1.1921e-07, -1.6424e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.7744e-04, -7.7837e+00, -9.7070e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4653e+01, -2.7418e-06, -1.2975e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 575it [00:12, 33.14it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7065e+01, -4.7684e-07, -1.4561e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.8610e-06, -1.2801e+01, -1.6201e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.0290e-03, -6.9034e+00, -1.0637e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4627e+01, -4.4107e-06, -1.2439e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.5497e-06, -1.4084e+01, -1.3951e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0214, -3.8769, -7.7216]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.7220e-06, -1.2200e+01, -1.4170e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.6616e-04, -8.2346e+00, -1.4022e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.0797e-06, -1.2055e+01, -1.5296e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.2613e-03, -6.1116e+00, -1.0080e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7155e+01, -3.3379e-06, -1.2629e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4709e-04, -8.9748e+00, -1.0795e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-20.7324,   0.0000, -17.5093]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 588it [00:14, 27.38it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1393e+01, -2.9206e-05, -1.0932e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.3379e-06, -1.2892e+01, -1.3993e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.1007e-05, -1.0338e+01, -1.1664e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4084e+01, -9.5367e-07, -1.5365e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1165e+01, -1.8358e-05, -1.2376e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0234,  -3.7656, -12.3555]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0377, -3.3346, -6.5787]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5536e+01, -1.0729e-06, -1.3957e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 596it [00:15, 24.21it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.7831e-04, -8.1878e+00, -1.5082e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.8168e-03, -6.3788e+00, -9.0458e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.5978e+00, -9.8462e-05, -1.0397e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4543e-05, -1.1221e+01, -1.3643e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-2.5755, -0.0833, -5.5599]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.2970e+00, -9.3217e-05, -1.3432e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 602it [00:15, 21.80it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.8214e-06, -1.1695e+01, -1.4453e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.9605e-07, -1.5025e+01, -1.5224e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5060e+01, -8.4638e-06, -1.1719e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.9444e-03, -5.3604e+00, -8.3633e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 606it [00:16, 19.86it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.7643e-05, -1.0961e+01, -1.5488e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4306e+01, -3.8147e-06, -1.2644e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.1921e-07, -1.6137e+01, -1.8083e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 609it [00:16, 18.48it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0791e+01, -2.2530e-05, -1.3161e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.8610e-06, -1.2898e+01, -1.4701e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.9373e+01, -1.1921e-07, -1.5936e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 612it [00:17, 17.15it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.0266e-06, -1.4295e+01, -1.3486e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4314e+01, -1.0729e-06, -1.4571e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 614it [00:17, 16.30it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.0212e-05, -9.5782e+00, -1.3816e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.7039e-03, -5.6014e+00, -1.2392e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 616it [00:17, 14.62it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6785e+01, -2.1458e-06, -1.3100e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.9073e-06, -1.3332e+01, -1.5134e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 618it [00:18, 12.81it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.5367e+01, -1.8747e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4708e+01, -1.9073e-06, -1.3450e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 620it [00:18, 12.05it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5828e+01, -9.5367e-07, -1.3990e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 621it [00:18, 11.78it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.3564e-03, -6.6225e+00, -1.0581e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 622it [00:18, 11.28it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.9802e-06, -1.2771e+01, -1.5737e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 623it [00:18,  9.76it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-2.0324e+01, -4.7684e-07, -1.4605e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 624it [00:18,  9.57it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.3446e-07, -1.4147e+01, -1.6564e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 625it [00:19,  8.56it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.5391e-05, -1.0621e+01, -1.3869e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 626it [00:19,  8.20it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1631e+01, -1.1325e-05, -1.2941e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 627it [00:19,  8.04it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[  0.0000, -16.8561, -17.4937]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 628it [00:19,  7.84it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.8258e-03, -4.9912e+00, -1.2198e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 629it [00:19,  6.23it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1598e+01, -2.4199e-05, -1.1109e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 630it [00:19,  6.53it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.0080e-05, -1.0859e+01, -1.0106e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 631it [00:20,  6.69it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.0994e-06, -1.2942e+01, -1.4106e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 632it [00:20,  6.67it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5225e+01, -1.6689e-06, -1.3448e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 633it [00:20,  6.25it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.1260e-06, -1.2244e+01, -1.4775e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 634it [00:20,  6.54it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5470e+01, -5.9605e-07, -1.4788e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 635it [00:20,  6.61it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6368e+01, -5.9605e-07, -1.4396e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 636it [00:20,  6.74it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2481e+01, -4.5299e-06, -1.4126e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 637it [00:20,  7.06it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.7486e-04, -8.2307e+00, -1.1678e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 638it [00:21,  7.23it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0664e+01, -6.9034e-04, -7.3132e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 639it [00:21,  6.88it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.8412e-06, -1.3390e+01, -1.2352e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 640it [00:21,  7.07it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.1921e-06, -1.4134e+01, -1.4655e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 641it [00:21,  7.04it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[ -3.9645,  -0.0192, -13.0797]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 642it [00:21,  6.55it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5512e+01, -1.0729e-06, -1.3953e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 643it [00:21,  6.30it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.6993e-05, -9.6641e+00, -1.2559e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 644it [00:21,  6.48it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.9345e-04, -8.3753e+00, -9.6741e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 645it [00:22,  6.35it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3628e+01, -8.9407e-06, -1.1777e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 646it [00:22,  6.69it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.1723e-06, -1.3108e+01, -1.3077e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 647it [00:22,  7.24it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.8966e+00, -6.6993e-05, -1.1000e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 648it [00:22,  5.40it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.1729e+00, -1.0157e-03, -8.3018e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 649it [00:22,  5.25it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-9.0160e-03, -4.7239e+00, -9.2659e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 650it [00:23,  5.70it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.9377e-05, -9.6319e+00, -1.2470e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 651it [00:23,  6.23it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7504e+01, -2.3842e-07, -1.5318e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 652it [00:23,  6.26it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.3192e-05, -9.8438e+00, -1.0816e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 653it [00:23,  6.63it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.8398e-05, -9.9454e+00, -1.4632e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 654it [00:23,  5.06it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.3446e-07, -1.3975e+01, -1.8345e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 655it [00:24,  4.50it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4537e+01, -2.9802e-06, -1.2900e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 656it [00:24,  5.08it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0634,  -2.7900, -11.2861]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 657it [00:24,  5.52it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.0861e-05, -1.0891e+01, -1.3012e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 658it [00:24,  4.65it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0262e+01, -1.3064e-04, -9.2540e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 659it [00:24,  5.31it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.2875e-05, -1.1277e+01, -1.5322e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 660it [00:24,  5.54it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-20.1328,   0.0000, -16.8672]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 661it [00:25,  5.77it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.3820e-04, -7.5826e+00, -1.0453e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 662it [00:25,  5.91it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3722e-05, -1.0721e+01, -1.3293e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 663it [00:25,  4.26it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.5272e-05, -1.1326e+01, -1.1230e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 664it [00:25,  5.01it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.7684e-07, -1.4967e+01, -1.6040e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 665it [00:25,  4.95it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.3446e-07, -1.3975e+01, -1.8345e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 666it [00:26,  4.80it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.1526e-07, -1.4085e+01, -1.6696e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 667it [00:26,  5.54it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0316, -3.5667, -5.8714]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0410e+01, -5.4239e-05, -1.0633e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 669it [00:26,  7.07it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-4.5614, -0.0106, -9.3485]], device='cuda:0', grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3653e+01, -2.3722e-05, -1.0701e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 671it [00:26,  7.87it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.9407e-06, -1.2526e+01, -1.2136e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 672it [00:26,  7.11it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.1723e-06, -1.2391e+01, -1.7505e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 673it [00:27,  6.16it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-06, -1.3191e+01, -1.4599e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 674it [00:27,  5.05it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0825e+01, -2.3246e-05, -1.2601e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 675it [00:27,  5.77it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.4836e-06, -1.2453e+01, -1.3406e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 676it [00:27,  6.32it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7424e+01, -4.7684e-07, -1.4676e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 677it [00:27,  6.85it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4518e+01, -1.2040e-05, -1.1365e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 678it [00:27,  7.29it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.2813e+00, -9.7628e-05, -1.2304e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 679it [00:27,  7.78it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.9112e+00, -5.3762e-05, -1.2388e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 680it [00:28,  7.85it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.4648e-04, -7.9730e+00, -1.3241e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 681it [00:28,  7.95it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.9245e-05, -9.8165e+00, -1.2279e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 682it [00:28,  8.10it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3792e+01, -3.3379e-06, -1.3002e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 683it [00:28,  7.88it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6230e+01, -3.6955e-06, -1.2547e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 684it [00:28,  8.21it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.8214e-06, -1.1695e+01, -1.4453e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 685it [00:28,  6.75it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6238e+01, -1.7881e-06, -1.3278e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 686it [00:28,  7.27it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.8809e+00, -6.4371e-05, -1.1231e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 687it [00:29,  7.19it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1125e+01, -1.5497e-05, -1.4157e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 688it [00:29,  7.23it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.8132e+01, -1.1921e-07, -1.5948e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 689it [00:29,  7.41it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4722e+01, -5.9605e-07, -1.5271e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 690it [00:29,  7.79it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0408,  -3.2204, -17.7908]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 691it [00:29,  8.02it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.1526e-07, -1.4382e+01, -1.6281e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 692it [00:29,  8.24it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.2186e-06, -1.2656e+01, -1.7239e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 693it [00:29,  6.53it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.2503e+00, -2.6223e-04, -1.3836e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 694it [00:29,  6.92it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5618e+01, -5.9605e-07, -1.4804e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 695it [00:30,  7.03it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.0186e-05, -9.9415e+00, -1.3100e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 696it [00:30,  6.00it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3788e+01, -3.0994e-06, -1.3071e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 697it [00:30,  6.74it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.0960e-03, -6.8175e+00, -1.3901e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 698it [00:30,  6.43it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.5643e-05, -1.0879e+01, -1.0990e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 699it [00:30,  6.92it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7114e+01, -2.3842e-07, -1.5233e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 700it [00:30,  7.17it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.1487e+00, -3.0525e-04, -1.1037e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 701it [00:30,  7.50it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.1458e-06, -1.3148e+01, -1.5435e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 702it [00:31,  7.57it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.3487e-03, -6.6146e+00, -1.1857e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 703it [00:31,  8.11it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6897e+01, -3.3379e-06, -1.2639e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 704it [00:31,  8.44it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-21.4297,   0.0000, -20.2988]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 705it [00:31,  8.46it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-5.3991e+00, -4.5960e-03, -9.6423e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 706it [00:31,  8.44it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.7684e-06, -1.2410e+01, -1.4083e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 707it [00:31,  8.71it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.2186e-06, -1.2709e+01, -1.5333e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 708it [00:31,  7.41it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0584e+01, -3.4570e-05, -1.1596e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 709it [00:32,  6.84it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.6285e+01, -1.6370e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 710it [00:32,  5.59it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.0398e-05, -1.0406e+01, -1.5645e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 711it [00:32,  5.86it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[  0.0000, -16.6411, -17.3428]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 712it [00:32,  5.81it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-06, -1.3021e+01, -1.6371e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 713it [00:32,  6.11it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[ -1.7852,  -0.1837, -10.4666]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 714it [00:32,  6.33it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.8316e+01, -1.1921e-07, -1.6521e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 715it [00:33,  6.13it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.6544e+00, -6.4848e-05, -1.4179e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 716it [00:33,  6.02it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.6354e-04, -9.2521e+00, -9.6017e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 717it [00:33,  6.47it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.0518e+00, -1.0178e-03, -8.7959e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 718it [00:33,  6.08it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-5.6209e+00, -3.7178e-03, -9.3206e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 719it [00:33,  5.13it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.6009e+01, -1.6136e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 720it [00:33,  5.69it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.5198e-03, -4.7702e+00, -1.2141e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 721it [00:34,  6.02it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7269e+01, -1.1921e-07, -1.5898e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 722it [00:34,  6.05it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3104e+01, -3.2186e-06, -1.3671e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 723it [00:34,  6.07it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6194e+01, -1.4305e-06, -1.3537e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 724it [00:34,  6.14it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4543e-05, -1.2878e+01, -1.1328e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 725it [00:34,  6.24it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0813, -2.5501, -9.9583]], device='cuda:0', grad_fn=<CatBackward0>)
# 726it [00:34,  6.33it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.6294e-06, -1.1813e+01, -1.5357e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 727it [00:35,  6.84it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.1723e-06, -1.2443e+01, -1.5479e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 728it [00:35,  5.93it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2655e+01, -4.8876e-06, -1.3313e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 729it [00:35,  6.33it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3570e+01, -5.1260e-06, -1.2471e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 730it [00:35,  6.96it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1496e+01, -2.7060e-05, -1.0987e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 731it [00:35,  7.22it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4901e-05, -1.1141e+01, -1.4719e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 732it [00:35,  7.45it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-9.2983e-06, -1.1787e+01, -1.3277e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 733it [00:35,  6.29it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5810e+01, -2.0146e-05, -1.0820e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 734it [00:36,  6.98it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.9193e-05, -1.1062e+01, -1.2586e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 735it [00:36,  7.46it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4186e-05, -1.1720e+01, -1.2014e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 736it [00:36,  8.02it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.6736e-04, -8.7033e+00, -1.3578e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 737it [00:36,  7.95it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-18.6072,   0.0000, -18.0195]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 738it [00:36,  7.95it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.8736e+01, -4.7684e-07, -1.4586e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 739it [00:36,  8.10it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.1219e-05, -1.3126e+01, -1.0863e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 740it [00:36,  8.52it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.9870e-06, -1.1742e+01, -1.6789e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 741it [00:36,  8.15it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-18.0981,   0.0000, -17.1645]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 742it [00:37,  8.06it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.5478e-03, -6.4820e+00, -1.1050e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 743it [00:37,  7.04it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.1126e-05, -1.2040e+01, -1.0257e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 744it [00:37,  7.10it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.9410e+01, -1.1921e-07, -1.6636e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 745it [00:37,  7.44it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1259e+01, -4.2914e-05, -1.0414e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 746it [00:37,  7.28it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.3508,  -1.2179, -11.3717]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 747it [00:37,  6.99it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.0746e-03, -6.8409e+00, -1.2239e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 748it [00:37,  6.12it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.2915e-06, -1.3888e+01, -1.2607e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 749it [00:38,  6.80it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3054e+01, -5.1260e-06, -1.2703e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 750it [00:38,  7.09it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.6028e-06, -1.2689e+01, -1.2877e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 751it [00:38,  6.58it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.0333e-06, -1.1873e+01, -1.7020e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 752it [00:38,  7.10it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.8100e+01, -2.8610e-06, -1.2778e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 753it [00:38,  7.60it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5227e+01, -3.2186e-06, -1.2717e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 754it [00:38,  8.11it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.0092, -4.7123, -8.9330]], device='cuda:0', grad_fn=<CatBackward0>)
# 755it [00:38,  8.22it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2561e+01, -3.6955e-06, -1.5320e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 756it [00:38,  8.20it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-20.8379,   0.0000, -16.9697]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 757it [00:39,  8.02it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.9507e-04, -7.8931e+00, -9.0142e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 758it [00:39,  8.21it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.5763e-07, -1.9082e+01, -1.4751e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 759it [00:39,  8.08it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0604,  -2.8377, -10.2420]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 760it [00:39,  8.08it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-18.5747,   0.0000, -19.0049]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 761it [00:39,  8.13it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1621e+01, -1.0490e-05, -1.3362e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 762it [00:39,  7.97it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4590e-04, -8.8576e+00, -1.2532e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 763it [00:39,  7.50it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3722e-05, -1.0680e+01, -1.4158e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.4024e+00, -9.5005e-05, -1.1290e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 765it [00:40,  7.11it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-5.0848e+00, -6.6320e-03, -7.7762e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 766it [00:40,  7.27it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3212e+01, -2.7418e-06, -1.3860e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 767it [00:40,  7.48it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.6689e-06, -1.3324e+01, -1.7160e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 768it [00:40,  7.68it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.3379e-06, -1.2641e+01, -1.5995e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 769it [00:40,  7.52it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4305e-06, -1.3918e+01, -1.4532e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 770it [00:40,  6.74it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.2650e-06, -1.2982e+01, -1.9195e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 771it [00:40,  7.26it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5605e+01, -4.8876e-06, -1.2266e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 772it [00:41,  7.39it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5557e+01, -8.3446e-07, -1.4323e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 773it [00:41,  7.52it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5162e+01, -3.3379e-06, -1.2695e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 774it [00:41,  7.41it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6067e+01, -1.7881e-06, -1.3269e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 775it [00:41,  7.42it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.5285e-05, -1.0352e+01, -1.2625e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 776it [00:41,  7.72it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0318e+01, -3.6954e-05, -1.2461e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 777it [00:41,  7.93it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7127e+01, -4.7684e-07, -1.4545e+01]], device='cuda:0',
# ...
#        grad_fn=<CatBackward0>)
# 900it [01:01,  5.93it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.5102e-06, -1.1963e+01, -1.3611e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 901it [01:01,  5.73it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.9245e-05, -9.8165e+00, -1.2279e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 902it [01:01,  6.40it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.5168e+01, -1.7519e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 903it [01:02,  4.96it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.0252e-05, -1.1840e+01, -1.2701e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 904it [01:02,  5.09it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7352e+01, -9.5367e-07, -1.3917e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 905it [01:02,  5.77it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.3656e-05, -9.6856e+00, -1.3434e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 906it [01:02,  6.56it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-6.9546e-04, -7.2819e+00, -1.1823e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 907it [01:02,  6.05it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6994e+01, -3.5763e-07, -1.5106e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 908it [01:02,  6.73it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2038e+01, -1.2398e-05, -1.1945e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 909it [01:03,  7.02it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-9.5775e-04, -7.3721e+00, -8.0205e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 910it [01:03,  7.55it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2491e+01, -5.4836e-06, -1.3263e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 911it [01:03,  7.79it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.0344e-05, -9.4708e+00, -1.2662e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 912it [01:03,  7.47it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-8.3446e-07, -1.4168e+01, -1.6613e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 913it [01:03,  7.45it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.5159e+01, -1.6752e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 914it [01:03,  6.41it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3785e+01, -1.5497e-06, -1.4561e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 915it [01:03,  6.27it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0223e+01, -3.7431e-05, -1.3678e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 916it [01:04,  6.75it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.3677e-04, -7.6119e+00, -1.0077e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 917it [01:04,  7.23it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0125,  -4.3875, -10.9249]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 918it [01:04,  7.65it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-06, -1.2943e+01, -1.6841e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 919it [01:04,  7.82it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.1921e-07, -1.6483e+01, -1.7307e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 920it [01:04,  8.14it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.8610e-06, -1.2801e+01, -1.6201e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 921it [01:04,  8.38it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6024e+01, -1.0729e-05, -1.1455e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 922it [01:04,  8.19it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.4107e-06, -1.2340e+01, -1.8254e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 923it [01:04,  8.46it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.6316e-04, -7.9301e+00, -1.2593e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# [{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3580e+01, -2.7418e-06, -1.3393e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 925it [01:05,  8.44it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-4.2298, -0.0149, -8.3196]], device='cuda:0', grad_fn=<CatBackward0>)
# 926it [01:05,  8.57it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.9629e-05, -9.5177e+00, -1.2008e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 927it [01:05,  7.52it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.5405e-05, -1.0340e+01, -1.2677e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 928it [01:05,  6.70it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.0729e-06, -1.3926e+01, -1.5734e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 929it [01:05,  6.41it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7941e+01, -1.1921e-07, -1.5822e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 930it [01:05,  6.66it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4075e+01, -1.5497e-06, -1.4123e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 931it [01:06,  6.92it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.2528e-03, -6.7903e+00, -8.9681e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 932it [01:06,  7.39it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2190e+01, -3.6239e-05, -1.0375e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 933it [01:06,  7.61it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0123e+01, -5.6384e-05, -1.1026e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 934it [01:06,  8.02it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.4435e-04, -8.8439e+00, -1.6161e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 935it [01:06,  8.27it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.4888e-04, -8.4866e+00, -1.0061e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 936it [01:06,  8.15it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.0109e+01, -5.6980e-05, -1.1027e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 937it [01:06,  8.36it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.8673e+00, -1.4447e-04, -1.2565e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 938it [01:06,  8.40it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-3.3855e-05, -1.0500e+01, -1.1972e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 939it [01:07,  8.04it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.5732e+01, -1.5679e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 940it [01:07,  7.01it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.3113e-06, -1.4584e+01, -1.3974e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 941it [01:07,  7.47it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5438e+01, -4.7684e-07, -1.5161e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 942it [01:07,  7.48it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.8596e-05, -1.1338e+01, -1.1910e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 943it [01:07,  7.63it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.7895e-05, -1.0668e+01, -1.2291e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 944it [01:07,  6.30it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7599e+01, -1.1921e-07, -1.6466e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 945it [01:07,  6.93it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.0266e-06, -1.3098e+01, -1.6894e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 946it [01:08,  5.76it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3829e+01, -1.4305e-06, -1.4511e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 947it [01:08,  6.19it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.2254e-04, -8.4729e+00, -1.1219e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 948it [01:08,  6.01it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6656e+01, -2.3842e-07, -1.5668e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 949it [01:08,  6.57it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.0245,  -3.7237, -11.3501]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 950it [01:08,  7.29it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3248e+01, -4.8876e-06, -1.2695e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 951it [01:08,  7.74it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-7.6410e-05, -9.5137e+00, -1.2845e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 952it [01:08,  6.70it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.9605e-07, -1.4532e+01, -1.5853e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 953it [01:09,  7.04it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2092e+01, -7.3909e-06, -1.3226e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 954it [01:09,  6.67it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[ -1.7852,  -0.1837, -10.4666]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 955it [01:09,  7.26it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6864e+01, -1.4305e-06, -1.3485e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 956it [01:09,  7.70it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-1.9073e-06, -1.3458e+01, -1.4649e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 957it [01:09,  8.03it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-5.1971e+00, -5.7147e-03, -8.7040e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 958it [01:09,  8.26it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.1457e-05, -1.0973e+01, -1.2359e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 959it [01:09,  8.42it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-2.0482e+01, -1.1921e-07, -1.6393e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 960it [01:09,  8.13it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.9068e+01, -8.3446e-07, -1.3951e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 961it [01:10,  8.42it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.0266e-06, -1.3377e+01, -1.4591e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 962it [01:10,  8.58it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.0633e-04, -8.8010e+00, -9.7932e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 963it [01:10,  6.40it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5357e+01, -1.0729e-06, -1.3903e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 964it [01:10,  6.65it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-5.7019e+00, -4.6429e-03, -6.6511e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 965it [01:10,  7.24it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5569e+01, -3.0994e-06, -1.2741e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 966it [01:10,  7.48it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.1815e-05, -1.0772e+01, -1.4062e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 967it [01:11,  6.25it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1574e+01, -1.6093e-05, -1.1918e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 968it [01:11,  6.70it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[ -0.2989,  -1.3535, -11.8545]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 969it [01:11,  6.42it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-5.6597e+00, -3.4987e-03, -1.1590e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 970it [01:11,  6.83it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.0385e-05, -1.0818e+01, -1.5087e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 971it [01:11,  6.33it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-4.2915e-06, -1.2804e+01, -1.3392e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 972it [01:12,  4.52it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-2.3842e-07, -1.5201e+01, -1.6764e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 973it [01:12,  4.25it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-5.0901e-05, -9.9200e+00, -1.3302e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 974it [01:12,  4.33it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.9449, -0.1558, -6.6724]], device='cuda:0', grad_fn=<CatBackward0>)
# 975it [01:12,  4.77it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.9652e+00, -3.5304e-04, -1.2093e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 976it [01:12,  5.29it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6860e+01, -1.4305e-06, -1.3482e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 977it [01:12,  5.57it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.5374e+00, -3.1800e-04, -9.0120e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 978it [01:13,  6.10it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.1344e+01, -1.6570e-05, -1.2271e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 979it [01:13,  6.46it/s][{'uniq_id': 0, 'answer': 'no'}] [1.0] tensor([[-0.5221, -0.9088, -5.6002]], device='cuda:0', grad_fn=<CatBackward0>)
# 980it [01:13,  6.57it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4331e+01, -6.4373e-06, -1.2048e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 981it [01:13,  6.50it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5037e+01, -2.7418e-06, -1.2908e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 982it [01:13,  6.62it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3219e+01, -6.9139e-05, -9.6055e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 983it [01:13,  7.07it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3957e+01, -3.6955e-06, -1.2764e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 984it [01:13,  7.29it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3615e+01, -5.3644e-06, -1.2390e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 985it [01:14,  7.78it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.2877e+01, -3.5763e-06, -1.3766e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 986it [01:14,  6.71it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.2620e+00, -2.8034e-04, -1.0719e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 987it [01:14,  6.73it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5735e+01, -9.5367e-07, -1.4096e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 988it [01:14,  7.33it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5287e+01, -1.7881e-06, -1.3338e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 989it [01:14,  7.68it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-7.1414e+00, -7.9255e-04, -1.4412e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 990it [01:14,  8.12it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.5650e+01, -7.1526e-07, -1.4340e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 991it [01:14,  8.24it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[ -3.2843,  -0.0382, -10.2648]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 992it [01:14,  8.51it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.4271e+01, -2.0266e-06, -1.3495e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 993it [01:15,  8.64it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6888e+01, -5.9605e-07, -1.4327e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 994it [01:15,  8.46it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.7929e+01, -9.5367e-07, -1.3926e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 995it [01:15,  8.37it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-8.9611e+00, -1.2862e-04, -1.4996e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 996it [01:15,  8.01it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[ -3.6323,  -0.0268, -10.4624]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 997it [01:15,  8.00it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.6811e+01, -5.9605e-07, -1.4441e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 998it [01:15,  7.99it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-1.3230e+01, -5.6265e-05, -9.8184e+00]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 999it [01:15,  8.25it/s][{'uniq_id': 0, 'answer': 'yes'}] [0] tensor([[-9.1954e+00, -1.0430e-04, -1.2777e+01]], device='cuda:0',
#        grad_fn=<CatBackward0>)
# 1000it [01:15, 13.18it/s]
# Accuracy:  0.904
