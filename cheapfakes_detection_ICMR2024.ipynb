# %% [markdown]
# ### Install environment

# %%
# !git clone https://thanhson28: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@github.com/thanhson28/cheapfakes_detection_icmr2024.git
# %cd cheapfakes_detection_icmr2024
# %cd /content/cheapfakes_detection_icmr2024
# !sed '1d' requirements.txt | xargs -I {} pip install {}
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1LqV1za_VKx2asDcniINCD5D6LXPciiKb
# %cd /content/cheapfakes_detection_icmr2024/fairseq
# !pip install ./
# !pip install "numpy<1.24"
# Out:
# Cloning into 'cheapfakes_detection_icmr2024'...
# remote: Enumerating objects: 1556, done.
# remote: Counting objects: 100% (1556/1556), done.
# remote: Compressing objects: 100% (1150/1150), done.
# remote: Total 1556 (delta 348), reused 1537 (delta 332), pack-reused 0
# Receiving objects: 100% (1556/1556), 30.32 MiB | 33.67 MiB/s, done.
# Resolving deltas: 100% (348/348), done.
# /content/cheapfakes_detection_icmr2024
# /content/cheapfakes_detection_icmr2024
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 59.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 77.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 796.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### INPUT_FOLDER structure:
# - INPUT_FOLDER should has structure as same as requirement of organizer, contain "test.json" as follow:\
# INPUT_FOLDER \
# ├── test.json \
# ├── test \
# │   ├── 0.jpg \
# │   ├── 100.png \
# │   ├── 101.jpg \
# │   ├── 102.jpg \
# - With "test/0.jpg" is an "img_local_path" in "test.json" for example.

# %% [markdown]
# ### SETUP Enviroment variables - you should change to adapt your data folder structure
# - INPUT_FOLDER: absulutely path to parent folder which contains images folder
# - DATA: absolutely path to test.json file of organizer
# - If the "img_local_path" in "test.json" is "test/0.jpg", the absulutely path to the image have to be IMG_PREFIX/test/0.jpg

# %%
# %env INPUT_FOLDER=/content/drive/MyDrive/cosmos/data/acm
# %env DATA=/content/drive/MyDrive/cosmos/data/acm/test.json
# Out:
# env: INPUT_FOLDER=/content/drive/MyDrive/cosmos/data/acm
# env: DATA=/content/drive/MyDrive/cosmos/data/acm/test.json

# %% [markdown]
# ### Run experiment for task 1

# %%
# %cd /content/cheapfakes_detection_icmr2024/run_scripts/snli_ve
# %env MASTER_PORT=7091
# %env PYTHONPATH=$PYTHONPATH:../../flops/

# %env user_dir=../../ofa_module
# %env bpe_dir=../../utils/BPE
# dev or test
# %env split=test
# %env path=/content/cheapfakes_detection_icmr2024/checkpoint.gendata1_testtrain12_mixed_4000.best_snli_score_0.9090.pt
# %env result_path=../../results/snli_ve
# %env selected_cols=0,2,3,4,5

# !CUDA_VISIBLE_DEVICE=0 python ../../inference_batch_task1.py ${DATA}\
    --path=${path}\
    --user-dir=${user_dir} \
    --task=snli_ve \
    --batch-size=2 \
    --log-format=simple --log-interval=10 \
    --seed=7 \
    --gen-subset=${split} \
    --results-path=${result_path} \
    --fp16 \
    --num-workers=0 \
    --model-overrides="{\"data\":\"${data}\",\"bpe_dir\":\"${bpe_dir}\",\"selected_cols\":\"${selected_cols}\"}"
# Out:
# /content/cheapfakes_detection_icmr2024/run_scripts/snli_ve
# env: MASTER_PORT=7091
# env: PYTHONPATH=$PYTHONPATH:../../flops/
# env: user_dir=../../ofa_module
# env: bpe_dir=../../utils/BPE
# env: split=test
# env: path=/content/cheapfakes_detection_icmr2024/checkpoint.gendata1_testtrain12_mixed_4000.best_snli_score_0.9090.pt
# env: result_path=../../results/snli_ve
# env: selected_cols=0,2,3,4,5
# 2024-03-18 19:24:22.576814: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 19:24:22.576942: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %% [markdown]
# ### Run experiment for task 2
# * As recommend by Organizers, the "json" file should be th same format but caption will be located at "caption1"

# %% [markdown]
# #### SETUP Enviroment variables - you should change to adapt your data folder structure as same as task 1

# %%
# %env INPUT_FOLDER=/content/drive/MyDrive/cosmos/data/acm
# %env DATA=/content/drive/MyDrive/cosmos/data/acm/test.json
# Out:
# env: INPUT_FOLDER=/content/drive/MyDrive/cosmos/data/acm
# env: DATA=/content/drive/MyDrive/cosmos/data/acm/test.json

# %% [markdown]
# #### Run process

# %%
# %cd /content/cheapfakes_detection_icmr2024/run_scripts/snli_ve
# %env MASTER_PORT=7091
# %env PYTHONPATH=$PYTHONPATH:../../flops/

# %env user_dir=../../ofa_module
# %env bpe_dir=../../utils/BPE
# dev or test
# %env split=test
# %env path=/content/cheapfakes_detection_icmr2024/checkpoint.gendata1_testtrain12_mixed_4000.best_snli_score_0.9090.pt
# %env result_path=../../results/snli_ve
# %env selected_cols=0,2,3,4,5

# !CUDA_VISIBLE_DEVICE=0 python ../../inference_batch_task2.py ${DATA}\
    --path=${path}\
    --user-dir=${user_dir} \
    --task=snli_ve \
    --batch-size=2 \
    --log-format=simple --log-interval=10 \
    --seed=7 \
    --gen-subset=${split} \
    --results-path=${result_path} \
    --fp16 \
    --num-workers=0 \
    --model-overrides="{\"data\":\"${data}\",\"bpe_dir\":\"${bpe_dir}\",\"selected_cols\":\"${selected_cols}\"}"
# Out:
# /content/cheapfakes_detection_icmr2024/run_scripts/snli_ve
# env: MASTER_PORT=7091
# env: PYTHONPATH=$PYTHONPATH:../../flops/
# env: user_dir=../../ofa_module
# env: bpe_dir=../../utils/BPE
# env: split=test
# env: path=/content/cheapfakes_detection_icmr2024/checkpoint.gendata1_testtrain12_mixed_4000.best_snli_score_0.9090.pt
# env: result_path=../../results/snli_ve
# env: selected_cols=0,2,3,4,5
# 2024-03-18 19:39:10.455064: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 19:39:10.455126: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
